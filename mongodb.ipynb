# %% [markdown]
# # **MongoDB(NoSQL Document Database) Document Management**
# #### `Name & Surname: Abdulkadir Arslan`

# %% [markdown]
# ### **1.** I installed and configured MongoDB on my PC, I made a native installation for my operating system (Windows). I created a database called *****first_database***** and a collection called *****first_collection***** via GUI. I printed both all databases and collections, below on the **3.** step.

# %% [markdown]
# ### **2.** *Installation of the Library & Imports*

# %%
#!pip install pymongo

# %%
from pymongo import MongoClient
import random

# %% [markdown]
# ### **3.** Connecting to the MongoDB Cluster via Connection String & Testing the Database Connection

# %%
connection_string = 'mongodb+srv://akadirarslanka:IQpI4ObyZp7Qxmls@cluster0.yrwxybd.mongodb.net/'

try:
    client = MongoClient(connection_string)

    db = client['test_database']
    collection = db['big_data_task1']

    if client:
        print("Connected to MongoDB Atlas successfully!")
        
        print("Databases:", client.list_database_names())
        
        for db_name in client.list_database_names():
            db = client[db_name]
            print(f"Collections in {db_name}:", db.list_collection_names())

except Exception as e:
    print("Connection error:", e)
# Out:
# Connected to MongoDB Atlas successfully!
# Databases: ['first_database', 'sample_mflix', 'test_database', 'admin', 'local']
# Collections in first_database: ['first_collection']
# Collections in sample_mflix: ['comments', 'embedded_movies', 'theaters', 'movies', 'users', 'sessions']
# Collections in test_database: ['big_data_task1']
# Collections in admin: []
# Collections in local: ['oplog.rs']

# %% [markdown]
# #### **4.**  The Python Application for Creating Random `Book` JSON-Style Documents

# %%
def generate_book():
    book_data = {
        'Moby Dick': {'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851},
        '1984': {'author': 'George Orwell', 'genre': 'Dystopian', 'pages': 328, 'published': 1949},
        'To Kill a Mockingbird': {'author': 'Harper Lee', 'genre': 'Drama', 'pages': 281, 'published': 1960},
        'The Great Gatsby': {'author': 'F. Scott Fitzgerald', 'genre': 'Historical', 'pages': 218, 'published': 1925},
        'War and Peace': {'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
    }
    
    title = random.choice(list(book_data.keys()))
    data = book_data[title]
    
    book = {
        'title': title,
        'author': data['author'],
        'genre': data['genre'],
        'pages': data['pages'],
        'published': data['published']
    }
    
    return book

books = [generate_book() for _ in range(100)]

result = collection.insert_many(books)

print(f"Inserted {len(result.inserted_ids)} book documents.")
# Out:
# Inserted 100 book documents.

# %% [markdown]
# #### **5.** The Python Application to Demonstrate How to `INSERT`, `QUERY`, `UPDATE`, AND `DELETE` the Documents

# %%
# Insert a single book document
book_document1 = {'title': 'Pride and Prejudice', 'author': 'Jane Austen', 'genre': 'Romance', 'pages': 432, 'published': 1813}
result = collection.insert_one(book_document1)
print(f"Inserted document with ID: {result.inserted_id}")

# Insert multiple book documents
book_documents = [
    {'title': 'Harry Potter and the Sorcerer\'s Stone', 'author': 'J.K. Rowling', 'genre': 'Fantasy', 'pages': 309, 'published': 1997},
    {'title': 'The Catcher in the Rye', 'author': 'J.D. Salinger', 'genre': 'Literary Fiction', 'pages': 234, 'published': 1951}
]
result = collection.insert_many(book_documents)
print(f"Inserted {len(result.inserted_ids)} documents")
# Out:
# Inserted document with ID: 6630a8ce4f3c0684e9c91063
# Inserted 2 documents

# %%
# Update a single book document
query_single = {'title': 'The Catcher in the Rye'}
new_values_single = {'$set': {'pages': 250}}
result_single = collection.update_one(query_single, new_values_single)
print(f"Matched {result_single.matched_count} document and modified {result_single.modified_count} document")

# Update multiple book documents:
# Update documents where pages is less than 300
query_multiple = {'pages': {'$lt': 300}}
# Double the page count
new_values_multiple = {'$mul': {'pages': 2}}  
result_multiple = collection.update_many(query_multiple, new_values_multiple)
print(f"Matched {result_multiple.matched_count} documents and modified {result_multiple.modified_count} documents")
# Out:
# Matched 1 document and modified 1 document
# Matched 42 documents and modified 42 documents

# %%
# Find a specific book document
query_single = {'title': '1984'}
result_single = collection.find_one(query_single)
print(f"Found document: {result_single}")

# Find multiple book documents:
# Find documents where pages is greater than 500
query_multiple = {'pages': {'$gt': 500}}  
results_multiple = collection.find(query_multiple)
for result in results_multiple:
    print(result)
# Out:
# Found document: {'_id': ObjectId('6630a8cd4f3c0684e9c91000'), 'title': '1984', 'author': 'George Orwell', 'genre': 'Dystopian', 'pages': 328, 'published': 1949}
# {'_id': ObjectId('6630439f112b6998050f2c5a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c5b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c5e'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c63'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c65'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c67'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c68'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c6b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c6c'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c6e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c74'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c76'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c77'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c7a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c7e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c81'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c83'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c86'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c88'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c89'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c91'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c93'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c94'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c95'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c99'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2c9a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c9b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2c9c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2c9d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2ca2'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2ca4'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2ca6'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2ca7'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2ca8'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2caa'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2cad'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2cae'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2caf'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2cb1'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2cb2'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2cb3'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2cb5'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630439f112b6998050f2cb6'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2cb8'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2cb9'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630439f112b6998050f2cbb'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2cbc'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630439f112b6998050f2cbd'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac7022f'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70230'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70231'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70232'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70233'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70235'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70236'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70237'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70238'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7023a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac7023b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7023c'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac7023d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac7023f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70240'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70241'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70242'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70245'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70246'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70247'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70248'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7024b'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac7024d'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac7024e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70250'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70251'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70252'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70253'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70254'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70255'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70256'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70258'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7025b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7025c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7025f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70260'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70261'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70262'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70265'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70269'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac7026b'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70270'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70272'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70273'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70275'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70277'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70279'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7027a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac7027b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7027c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7027d'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7027e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70280'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70281'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac70282'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70283'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70285'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70286'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70288'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1caf9072afd9ac70289'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7028b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1caf9072afd9ac7028e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1caf9072afd9ac70290'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997b2'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997b3'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997b5'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997b6'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997b8'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997b9'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997bb'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997bc'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997be'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997bf'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997c1'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997c2'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997c9'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997cb'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997cc'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997ce'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997d3'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997d5'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997d8'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997d9'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997da'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997dd'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997de'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997df'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997e0'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997e2'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997e3'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997e6'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997e8'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997e9'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997ea'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997eb'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997ec'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997ed'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed3997f4'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997f5'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997f6'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed3997f9'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997fa'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997fc'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997fe'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed3997ff'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed399801'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed399803'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed399804'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed399805'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed399806'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1e4663e16a9ed399808'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed39980a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed39980b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1e4663e16a9ed39980c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed39980d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1e4663e16a9ed399814'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0129'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc012a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc012b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc012c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc012f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0131'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0132'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0134'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0138'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc0139'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc013a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc013b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc013c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc013d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc013e'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc013f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0141'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0142'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0143'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0144'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc0146'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0147'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc014c'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc014f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0151'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc0152'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0153'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0154'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0158'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc015b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc015c'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc015e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc015f'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc0161'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0164'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc0166'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0169'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc016a'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc016b'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc016c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc016d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc016e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0170'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0172'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0173'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc0178'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc017c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0180'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0181'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0182'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a1f103581429a7fc0183'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0185'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc0187'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a1f103581429a7fc018a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a1f103581429a7fc018b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1902'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1903'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1904'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1906'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1908'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a190b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a190d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a190f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1911'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1912'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1913'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1915'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1916'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1917'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1918'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1919'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a191a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a191b'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a191d'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a191e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1921'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1922'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1923'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1925'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1927'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1928'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a192a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a192b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a192c'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a192d'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a192f'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1931'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1935'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1937'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1938'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1939'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a193a'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a193c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a193e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a193f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1940'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1942'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1946'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1947'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1948'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1949'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a194a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a194c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a194d'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a194e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1953'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1954'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1955'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1956'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1957'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1958'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a195a'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a195c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a195d'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a195e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a195f'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a20a0103120b058a1961'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a20a0103120b058a1962'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a20a0103120b058a1964'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a1969'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a196d'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a196e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a196f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a2160103120b058a1971'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a1974'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a1975'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a1976'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a1977'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a1978'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a1979'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a197a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a2160103120b058a197b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a197c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a2160103120b058a197d'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a2160103120b058a197f'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a1981'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a2160103120b058a1985'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a2160103120b058a1986'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a1989'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a198b'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a2160103120b058a198c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a2160103120b058a198e'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# ...
# {'_id': ObjectId('6630a7fe0819a29330a93a36'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a39'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a3a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a3b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a3c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a3d'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a41'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a42'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a43'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a44'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a46'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a47'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a48'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a4d'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a4e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a4f'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a54'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a55'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a56'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a58'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a5c'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a5d'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a5f'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a61'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a63'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a66'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a68'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a69'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a70'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a71'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a72'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a74'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a75'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a78'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a79'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a7fe0819a29330a93a7b'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a7c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a7fe0819a29330a93a7f'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a7fe0819a29330a93a81'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91002'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91003'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91005'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91006'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91008'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9100a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9100e'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9100f'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91010'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91011'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91012'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91013'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91014'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91016'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91017'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91019'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9101c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9101e'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9101f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91020'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91022'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91025'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91026'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91027'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91029'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9102a'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9102b'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9102c'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91031'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91032'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91033'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91035'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91036'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91037'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91038'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91039'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9103a'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9103d'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9103e'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9103f'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91040'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91041'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91042'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91043'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91045'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91048'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91049'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9104c'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9104f'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91050'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91051'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91052'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91053'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91057'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91058'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9105a'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9105b'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9105d'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c9105f'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91060'), 'title': 'Moby Dick', 'author': 'Herman Melville', 'genre': 'Adventure', 'pages': 635, 'published': 1851}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91061'), 'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'genre': 'Drama', 'pages': 562, 'published': 1960}
# {'_id': ObjectId('6630a8cd4f3c0684e9c91062'), 'title': 'War and Peace', 'author': 'Leo Tolstoy', 'genre': 'Historical fiction', 'pages': 1225, 'published': 1869}

# %%
# Delete a single book document
query_single_delete = {'title': 'Moby Dick'}
result_single_delete = collection.delete_one(query_single_delete)
print(f"Deleted {result_single_delete.deleted_count} document")

# Delete multiple book documents
query_multiple_delete = {'pages': {'$lte': 400}}  # Delete documents where pages is less than or equal to 400
result_multiple_delete = collection.delete_many(query_multiple_delete)
print(f"Deleted {result_multiple_delete.deleted_count} documents")
# Out:
# Deleted 1 document
# Deleted 20 documents
